# %% [markdown]
# ## Text classification using Neural Networks
#
# The goal of this notebook is to learn to use Neural Networks for text classification.
#
# In this notebook, we will:
# - Train a shallow model with learning embeddings
# - Download pre-trained embeddings from Glove
# - Use these pre-trained embeddings

# %%
## Tensorflow GPU disabled by default. Comment the following lines to enable GPU if you have a working CUDA installation.
import tensorflow as tf

try:
    # Disable all GPUs
    tf.config.set_visible_devices([], 'GPU')

    visible_devices = tf.config.get_visible_devices()
    for device in visible_devices:
        assert device.device_type != 'GPU'
    print("GPUs disabled, using CPU.")

except:
    # Invalid device or cannot modify virtual devices once initialized.
    pass
# Out:
# 2026-07-23 02:51:06.422910: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 02:51:06.423328: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-23 02:51:06.469751: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-23 02:51:07.501072: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-23 02:51:07.501400: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# GPUs disabled, using CPU.
# 2026-07-23 02:51:08.496151: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ## The BBC topic classification dataset
#
# The BBC provides some benchmark topic classification datasets in English at: http://mlg.ucd.ie/datasets/bbc.html.
#
# The raw text (encoded with the latin-1 character encoding) of the news can be downloaded as a ZIP archive:

# %%
import os
import os.path as op
import zipfile
from urllib.request import urlretrieve

BBC_DATASET_URL = "http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip"
zip_filename = BBC_DATASET_URL.rsplit('/', 1)[1]
BBC_DATASET_FOLDER = 'bbc'
if not op.exists(zip_filename):
    print("Downloading %s to %s..." % (BBC_DATASET_URL, zip_filename))
    urlretrieve(BBC_DATASET_URL, zip_filename)

if not op.exists(BBC_DATASET_FOLDER):
    with zipfile.ZipFile(zip_filename, 'r') as f:
        print("Extracting contents of %s..." % zip_filename)
        f.extractall('.')

# %% [markdown]
# Each of the five folders contains text files from one of the five topics:

# %%
target_names = sorted(folder for folder in os.listdir(BBC_DATASET_FOLDER)
                      if op.isdir(op.join(BBC_DATASET_FOLDER, folder)))
target_names
# Out:
# ['business', 'entertainment', 'politics', 'sport', 'tech']

# %%
# Example of a file in the "business" category
with open(op.join(BBC_DATASET_FOLDER, 'business', '001.txt'), 'rb') as f:
    print(f.read().decode('latin-1')[:500] + '...')
# Out:
# Ad sales boost Time Warner profit
#
# Quarterly profits at US media giant TimeWarner jumped 76% to $1.13bn (Â£600m) for the three months to December, from $639m year-earlier.
#
# The firm, which is now one of the biggest investors in Google, benefited from sales of high-speed internet connections and higher advert sales. TimeWarner said fourth quarter sales rose 2% to $11.1bn from $10.9bn. Its profits were buoyed by one-off gains which offset a profit dip at Warner Bros, and less users for AOL.
#
# Time ...

# %% [markdown]
# Let's randomly partition the text files in a training and test set while recording the target category of each file as an integer:

# %%
import numpy as np
from sklearn.model_selection import train_test_split

target = []
filenames = []
for target_id, target_name in enumerate(target_names):
    class_path = op.join(BBC_DATASET_FOLDER, target_name) # e.g. 'bbc/business'
    for filename in sorted(os.listdir(class_path)):
        filenames.append(op.join(class_path, filename))
        target.append(target_id)

target = np.asarray(target, dtype=np.int32)
target_train, target_test, filenames_train, filenames_test = train_test_split(
    target, filenames, test_size=200, random_state=0)

# %% [markdown]
# What we now have is pairs of target labels (which category the document belongs to) and filenames (where the document is stored on disk):

# %%
target_train[:5], filenames_train[:5]
# Out:
# (array([0, 1, 3, 4, 3], dtype=int32),
#  ['bbc/business/475.txt',
#   'bbc/entertainment/152.txt',
#   'bbc/sport/127.txt',
#   'bbc/tech/095.txt',
#   'bbc/sport/464.txt'])

# %%
size_in_bytes = sum([len(open(fn, 'rb').read()) for fn in filenames_train])
print("Training set size: %0.3f MB" % (size_in_bytes / 1e6))
# Out:
# Training set size: 4.582 MB

# %% [markdown]
# This dataset is small so we can load everything into memory right now (which simplifies our code later). If we had substantially more data, we would need to use a `tf.data.Dataset` to stream it from disk in batches during training.

# %%
texts_train = [open(fn, 'rb').read().decode('latin-1') for fn in filenames_train]
texts_test = [open(fn, 'rb').read().decode('latin-1') for fn in filenames_test]

# %% [markdown]
# ## A first baseline model
#
# For simple topic classification problems, one should always try a simple method first. Let's try using a `CountVectorizer` followed by `LogisticRegression` as a baseline. What this will do is:
#
# - Convert the text documents to a matrix of token counts (each row is a document, each column is a word, each cell is the count of the word in the document)
# - Train a logistic regression model on this matrix
#
# It's a very efficient method and should give us a strong baseline to compare our deep learning method against.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Understanding what the CountVectorizer does
vectorizer = CountVectorizer(max_features=2000) # only keep the 2000 most frequent words
X_train = vectorizer.fit_transform(texts_train)

# Compare the content of the first document with the vocabulary
print("Start of the first document:")
print(texts_train[0][0:100] + '...')
print('----------')
print("Sampling of vocabulary counts in the document:")
for word, count in zip(vectorizer.get_feature_names_out()[200:210], X_train.toarray()[0][200:210]):
    print(word, count)
# Out:
# Start of the first document:
# Watchdog probes Vivendi bond sale
#
# French stock market regulator AMF has filed complaints against me...
# ----------
# Sampling of vocabulary counts in the document:
# bank 2
# bankruptcy 0
# banks 0
# barcelona 0
# based 0
# basic 0
# basis 1
# bath 0
# battle 0
# bbc 0

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline


text_classifier = make_pipeline(
    CountVectorizer(max_features=2000),
    LogisticRegression(max_iter=1000),
)

# %%
# %time _ = text_classifier.fit(texts_train, target_train)
# Out:
# CPU times: user 24.1 s, sys: 0 ns, total: 24.1 s
# Wall time: 1.17 s

# %% [markdown]
# Let's check the accuracy of this baseline model on the test set:

# %%
text_classifier.score(texts_test, target_test)
# Out:
# 0.96

# %% [markdown]
# Approximately 95 percent testing accuracy on a very simple baseline. It's quite unlikely that we can significantly beat that baseline with a more complex deep learning based model. This is simply not a complex task - we wouldn't expect to see this level of performance from a simple model on a real-world text classification problem. Let's move on, and see how well we can do with a simple neural network.

# %% [markdown]
# ### Preprocessing text for the (supervised) CBOW model
#
# We will implement a simple classification model in Keras. Raw text requires (sometimes a lot of) preprocessing.
#
# The following cells uses Keras to preprocess text:
# - using a tokenizer. This converts the texts into sequences of indices representing the `20000` most frequent words
# - sequences have different lengths, so we pad them (add 0s at the end until the sequence is of length `1000`). For example, if we were padding to three words, and we had a sequence of just "dog", we would pad it to "[\<dog token\>,0,0]".
# - we convert the output classes as 1-hot encodings

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

MAX_NB_WORDS = 20000

# vectorize the text samples into a 2D integer tensor
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
print(f'Example of word_index: {list(word_index.items())[:5]}')
# Out:
# Found 30995 unique tokens.
# Example of word_index: [('the', 1), ('to', 2), ('of', 3), ('and', 4), ('a', 5)]

# %% [markdown]
# Tokenized sequences are converted to list of token ids (with an integer code). We can convert them back to text to see what they now look like:

# %%
index_to_word = dict((i, w) for w, i in tokenizer.word_index.items())

# %%
print(f'Original text:          {texts_train[0].split(" ")[0:4]}')
print(f'Tokenized text:         {sequences[0][0:4]}')
print(f'Converted back to text: {[index_to_word.get(i, "UNK") for i in sequences[0][0:4]]}')
# Out:
# Original text:          ['Watchdog', 'probes', 'Vivendi', 'bond']
# Tokenized text:         [1857, 9454, 5251, 1973]
# Converted back to text: ['watchdog', 'probes', 'vivendi', 'bond']

# %% [markdown]
# Let's have a closer look at the tokenized sequences:

# %%
seq_lens = [len(s) for s in sequences]
print("average length: %0.1f" % np.mean(seq_lens))
print("max length: %d" % max(seq_lens))
# Out:
# average length: 382.6
# max length: 4355

# %%
import matplotlib.pyplot as plt

plt.hist(seq_lens, bins=50);

# %% [markdown]
# We can see that while we do have sequences up to 4355 words long, the vast majority of sequences are less than 1000 words long. We can use this information to truncate or pad all the sequences to 1000 symbols to build the training set. This will simplify our model and speed up training.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences


MAX_SEQUENCE_LENGTH = 1000

# Make all sequences exactly 1000 words long
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2025, 1000)
# Shape of data test tensor: (200, 1000)

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(target_train)
print('Shape of label tensor:', y_train.shape)
# Out:
# Shape of label tensor: (2025, 5)

# %% [markdown]
# ### A simple supervised CBOW model in Keras
#
# The following computes a very simple model, as described in [fastText](https://github.com/facebookresearch/fastText):
#
# <img src="https://raw.githubusercontent.com/UofT-DSI/deep_learning/58b409e83f4294b293d6f763abf889d0a0fa1ddf/03_instructional_team/markdown_slides/images/svg_files/06_fasttext.svg" style="width: 600px;" />
#
# - Build an embedding layer mapping each word to a vector representation
# - Compute the vector representation of all words in each sequence and average them
# - Add a dense layer to output 5 classes

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling1D, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

EMBEDDING_DIM = 50
N_CLASSES = len(target_names) 

model = Sequential([
    Embedding(MAX_NB_WORDS, EMBEDDING_DIM, trainable=True), # Just like we've seen in previous labs
    GlobalAveragePooling1D(), # This layer averages the embeddings of all words in the sequence
    Dense(N_CLASSES, activation='softmax') # This layer outputs a probability distribution over the 5 classes
])

model.compile(
    loss='categorical_crossentropy', 
    optimizer=Adam(learning_rate=0.01),
    metrics=['accuracy']
)

# %%
model.fit(x_train, y_train, validation_split=0.1,
          epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3611 - loss: 1.4862 - val_accuracy: 0.4975 - val_loss: 1.2825
# Epoch 2/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6290 - loss: 1.0598 - val_accuracy: 0.7635 - val_loss: 0.7166
# Epoch 3/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8370 - loss: 0.5537 - val_accuracy: 0.9113 - val_loss: 0.3951
# Epoch 4/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9276 - loss: 0.3020 - val_accuracy: 0.9163 - val_loss: 0.2852
# Epoch 5/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9237 - loss: 0.2478 - val_accuracy: 0.8916 - val_loss: 0.3005
# Epoch 6/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8655 - loss: 0.4672 - val_accuracy: 0.6700 - val_loss: 1.1528
# Epoch 7/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8974 - loss: 0.3170 - val_accuracy: 0.9409 - val_loss: 0.2125
# Epoch 8/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9824 - loss: 0.0961 - val_accuracy: 0.9606 - val_loss: 0.1178
# Epoch 9/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9885 - loss: 0.0607 - val_accuracy: 0.9557 - val_loss: 0.1202
# Epoch 10/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9940 - loss: 0.0421 - val_accuracy: 0.9754 - val_loss: 0.1047

# %% [markdown]
# **Exercise**
#
# - Evaluate the model on the test set
# - Identify an example of a mis-classified document and display the text of the document

# %%
# Evaluate the model
predictions = model.predict(x_test)
predicted_text = np.argmax(predictions, axis=-1)
print(f'Text accuracy: {np.mean(predicted_text == target_test)}')

# misclassified texts
misclassifieds = np.nonzero(predicted_text != target_test)[0]
print(f'Number of misclassifieds are: {len(misclassifieds), len(target_test)}')

if len(misclassifieds) > 0:
    for i in range(2):
        words = misclassifieds[i]
        print(f'filenames: {filenames[words]}')
        print(f'predicted_text: {target_names[predicted_text[words]]}')
        print(f'original text: {target_names[target_test[words]]}')
        
        print(texts_test[i][:500] + 'to be continued.')
        print('============next misclassification==========')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Text accuracy: 0.95
# Number of misclassifieds are: (10, 200)
# filenames: bbc/business/003.txt
# predicted_text: business
# original text: politics
# Tate & Lyle boss bags top award
#
# Tate & Lyle's chief executive has been named European Businessman of the Year by a leading business magazine.
#
# Iain Ferguson was awarded the title by US publication Forbes for returning one of the UK's "venerable" manufacturers to the country's top 100 companies. The sugar group had been absent from the FTSE 100 for seven years until Mr Ferguson helped it return to growth. Tate's shares have leapt 55% this year, boosted by firming sugar prices and sales of its arto be continued.
# ============next misclassification==========
# filenames: bbc/business/013.txt
# predicted_text: business
# original text: politics
# Halo 2 sells five million copies
#
# Microsoft is celebrating bumper sales of its Xbox sci-fi shooter, Halo 2.
#
# The game has sold more than five million copies worldwide since it went on sale in mid-November, the company said. Halo 2 has proved popular online, with gamers notching up a record 28 million hours playing the game on Xbox Live. According to Microsoft, nine out of 10 Xbox Live members have played the game for an average of 91 minutes per session.
#
# The sequel to the best-selling Need for to be continued.
# ============next misclassification==========

# %% [markdown]
# ### Building more complex models
#
# **Exercise**
# - Copy the previous model, and add more complexity to it. You can try adding more layers, or using a different type of layer (e.g. LSTM, Conv1D, etc.)
# - Some examples of what you could do:
#     - Add a LSTM layer before the dense layer ([LSTM documentation](https://keras.io/layers/recurrent/#lstm))
#     - Add a Conv1D layer after the embedding layer ([Conv1D documentation](https://keras.io/layers/convolutional/#conv1d))
#     - Add more dense layers

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Embedding, LSTM, GlobalMaxPool1D, Input, Dropout, SpatialDropout1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import CategoricalCrossentropy
# model = Sequential([
#     # Your code here
# ])


stratification_labels = np.argmax(y_train, axis=1)

x_train_sub, x_val, y_train_sub, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=stratification_labels)

EMBEDDING_DIM = 50
N_CLASSES = len(target_names) 

model = Sequential([
    Input(shape=(x_train.shape[1],)),
    
    Embedding(MAX_NB_WORDS, EMBEDDING_DIM, trainable=True, embeddings_regularizer=l2(1e-5)), # Just like we've seen in previous labs
    
    SpatialDropout1D(0.15),
    
    Conv1D(64, 5, activation='relu', padding='same', kernel_regularizer=l2(1e-5)),
    
    MaxPooling1D(2),
    
    Conv1D(64, 5, padding='same', activation='relu'),
            
    LSTM(64, dropout=0.35), 
    
    Dense(32, activation='relu', kernel_regularizer=l2(1e-4)),
    
    Dropout(0.55),
        
    Dense(N_CLASSES, activation='softmax')
    
])

# Compile the model
model.compile(loss=CategoricalCrossentropy(label_smoothing=0.03),
              optimizer=Adam(learning_rate=2e-4, clipnorm=1.0), metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ (None, 1000, 50)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_10            │ (None, 1000, 50)       │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_20 (Conv1D)              │ (None, 1000, 64)       │        16,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_21 (Conv1D)              │ (None, 500, 64)        │        20,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,071,877 (4.09 MB)
#  Trainable params: 1,071,877 (4.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=10,
                               min_delta=1e-3,
                               restore_best_weights=True,
                               verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_delta=0.001, min_lr=1e-6, verbose=1)

history = model.fit(x_train_sub, y_train_sub, validation_data=(x_val, y_val),
          epochs=150, batch_size=32, callbacks=[early_stopping, reduce_lr], verbose=1)

output_test = model.predict(x_test)
test_classes = np.argmax(output_test, axis=-1)
print("Test accuracy:", np.mean(test_classes == target_test))
# Out:
# Epoch 1/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - accuracy: 0.2117 - loss: 1.6216 - val_accuracy: 0.2272 - val_loss: 1.6189 - learning_rate: 2.0000e-04
# Epoch 2/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.2414 - loss: 1.6169 - val_accuracy: 0.2840 - val_loss: 1.6148 - learning_rate: 2.0000e-04
# Epoch 3/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.2284 - loss: 1.6145 - val_accuracy: 0.2296 - val_loss: 1.6113 - learning_rate: 2.0000e-04
# Epoch 4/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.2494 - loss: 1.6065 - val_accuracy: 0.2321 - val_loss: 1.6033 - learning_rate: 2.0000e-04
# Epoch 5/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.3074 - loss: 1.5495 - val_accuracy: 0.4741 - val_loss: 1.3485 - learning_rate: 2.0000e-04
# Epoch 6/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.4006 - loss: 1.3471 - val_accuracy: 0.4519 - val_loss: 1.2333 - learning_rate: 2.0000e-04
# Epoch 7/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.4549 - loss: 1.2187 - val_accuracy: 0.5111 - val_loss: 1.1032 - learning_rate: 2.0000e-04
# Epoch 8/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5716 - loss: 1.0821 - val_accuracy: 0.6395 - val_loss: 0.9890 - learning_rate: 2.0000e-04
# Epoch 9/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.6179 - loss: 1.0170 - val_accuracy: 0.6370 - val_loss: 0.9015 - learning_rate: 2.0000e-04
# Epoch 10/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.6580 - loss: 0.8789 - val_accuracy: 0.6321 - val_loss: 0.8262 - learning_rate: 2.0000e-04
# Epoch 11/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.6617 - loss: 0.8154 - val_accuracy: 0.6617 - val_loss: 0.7792 - learning_rate: 2.0000e-04
# Epoch 12/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.7130 - loss: 0.7328 - val_accuracy: 0.6790 - val_loss: 0.7288 - learning_rate: 2.0000e-04
# Epoch 13/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.7315 - loss: 0.6912 - val_accuracy: 0.6914 - val_loss: 0.6818 - learning_rate: 2.0000e-04
# Epoch 14/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.7494 - loss: 0.6655 - val_accuracy: 0.7284 - val_loss: 0.6996 - learning_rate: 2.0000e-04
# Epoch 15/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.7895 - loss: 0.6002 - val_accuracy: 0.8123 - val_loss: 0.6625 - learning_rate: 2.0000e-04
# Epoch 16/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.8327 - loss: 0.5592 - val_accuracy: 0.8148 - val_loss: 0.6379 - learning_rate: 2.0000e-04
# Epoch 17/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.8889 - loss: 0.4931 - val_accuracy: 0.8469 - val_loss: 0.5361 - learning_rate: 2.0000e-04
# Epoch 18/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9228 - loss: 0.4151 - val_accuracy: 0.8840 - val_loss: 0.5043 - learning_rate: 2.0000e-04
# Epoch 19/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9352 - loss: 0.4130 - val_accuracy: 0.8864 - val_loss: 0.5363 - learning_rate: 2.0000e-04
# Epoch 20/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9494 - loss: 0.3622
# Epoch 20: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.9494 - loss: 0.3622 - val_accuracy: 0.8840 - val_loss: 0.5095 - learning_rate: 2.0000e-04
# Epoch 21/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9617 - loss: 0.3344 - val_accuracy: 0.9037 - val_loss: 0.4632 - learning_rate: 1.0000e-04
# Epoch 22/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9642 - loss: 0.3200 - val_accuracy: 0.9062 - val_loss: 0.4568 - learning_rate: 1.0000e-04
# Epoch 23/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9778 - loss: 0.3049 - val_accuracy: 0.9136 - val_loss: 0.4592 - learning_rate: 1.0000e-04
# Epoch 24/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9716 - loss: 0.3059
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.9716 - loss: 0.3059 - val_accuracy: 0.9062 - val_loss: 0.4624 - learning_rate: 1.0000e-04
# Epoch 25/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9710 - loss: 0.3084 - val_accuracy: 0.9111 - val_loss: 0.4535 - learning_rate: 5.0000e-05
# Epoch 26/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9722 - loss: 0.2935 - val_accuracy: 0.9136 - val_loss: 0.4624 - learning_rate: 5.0000e-05
# Epoch 27/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9698 - loss: 0.2990
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9698 - loss: 0.2990 - val_accuracy: 0.9086 - val_loss: 0.4651 - learning_rate: 5.0000e-05
# Epoch 28/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9698 - loss: 0.2964 - val_accuracy: 0.9086 - val_loss: 0.4611 - learning_rate: 2.5000e-05
# Epoch 29/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9753 - loss: 0.2956
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9753 - loss: 0.2956 - val_accuracy: 0.9086 - val_loss: 0.4626 - learning_rate: 2.5000e-05
# Epoch 30/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9778 - loss: 0.2828 - val_accuracy: 0.9062 - val_loss: 0.4634 - learning_rate: 1.2500e-05
# Epoch 31/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9765 - loss: 0.2945
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9765 - loss: 0.2945 - val_accuracy: 0.9111 - val_loss: 0.4629 - learning_rate: 1.2500e-05
# Epoch 32/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9747 - loss: 0.2922 - val_accuracy: 0.9136 - val_loss: 0.4616 - learning_rate: 6.2500e-06
# Epoch 33/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9784 - loss: 0.2896
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9784 - loss: 0.2896 - val_accuracy: 0.9086 - val_loss: 0.4656 - learning_rate: 6.2500e-06
# Epoch 34/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.9765 - loss: 0.2884 - val_accuracy: 0.9111 - val_loss: 0.4667 - learning_rate: 3.1250e-06
# Epoch 35/150
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9772 - loss: 0.2930
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9772 - loss: 0.2930 - val_accuracy: 0.9136 - val_loss: 0.4657 - learning_rate: 3.1250e-06
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test accuracy: 0.89

# %% [markdown]
# The final model combined convolutional layers with an LSTM to learn both local textual features and longer sequential dependencies. To limit overfitting, SpatialDropout1D, LSTM dropout, Dense-layer dropout, L2 regularization, label smoothing, early stopping, and learning-rate reduction were applied. The best model weights were restored from epoch 23, where the model achieved approximately 97.1% training accuracy and 91.1% validation accuracy. The final test accuracy was 89%, indicating reasonably consistent performance on unseen data.

# %% [markdown]
# ### Loading pre-trained embeddings
#
# The file `glove100K.100d.txt` is an extract of [Glove](http://nlp.stanford.edu/projects/glove/) Vectors, that were trained on English Wikipedia and the Gigaword 5 corpus. They differ from word2vec in the way the vectors are trained, but the idea is the same: each word is represented as a vector of `100` numbers.
#
# We extracted the `100 000` most frequent words for you, and the code below downloads them.

# %%
# Get pretrained Glove Word2Vec
URL_REPRESENTATIONS = "https://github.com/m2dsupsdlclass/lectures-labs/releases/download/0.3/glove100k.100d.zip"
ZIP_REPRESENTATIONS = "glove100k.100d.zip"
FILE_REPRESENTATIONS = "glove100K.100d.txt"

if not op.exists(ZIP_REPRESENTATIONS):
    print('Downloading from %s to %s...' % (URL_REPRESENTATIONS, ZIP_REPRESENTATIONS))
    urlretrieve(URL_REPRESENTATIONS, './' + ZIP_REPRESENTATIONS)

if not op.exists(FILE_REPRESENTATIONS):
    print("extracting %s..." % ZIP_REPRESENTATIONS)
    myzip = zipfile.ZipFile(ZIP_REPRESENTATIONS)
    myzip.extractall()
# Out:
# Downloading from https://github.com/m2dsupsdlclass/lectures-labs/releases/download/0.3/glove100k.100d.zip to glove100k.100d.zip...
# extracting glove100k.100d.zip...

# %%
embeddings_index = {}
embeddings_vectors = []
with open('glove100K.100d.txt', 'rb') as f:
    word_idx = 0
    for line in f:
        values = line.decode('utf-8').split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = word_idx
        embeddings_vectors.append(vector)
        word_idx = word_idx + 1

inv_index = {v: k for k, v in embeddings_index.items()}
print("found %d different words in the file" % word_idx)
# Out:
# found 100000 different words in the file

# %%
# Stack all embeddings in a large numpy array
glove_embeddings = np.vstack(embeddings_vectors)
glove_norms = np.linalg.norm(glove_embeddings, axis=-1, keepdims=True)
glove_embeddings_normed = glove_embeddings / glove_norms
print(glove_embeddings.shape)
# Out:
# (100000, 100)

# %%
def get_emb(word):
    idx = embeddings_index.get(word)
    if idx is None:
        return None
    else:
        return glove_embeddings[idx]

    
def get_normed_emb(word):
    idx = embeddings_index.get(word)
    if idx is None:
        return None
    else:
        return glove_embeddings_normed[idx]

# %%
get_emb("computer")
# Out:
# array([-1.6298e-01,  3.0141e-01,  5.7978e-01,  6.6548e-02,  4.5835e-01,
#        -1.5329e-01,  4.3258e-01, -8.9215e-01,  5.7747e-01,  3.6375e-01,
#         5.6524e-01, -5.6281e-01,  3.5659e-01, -3.6096e-01, -9.9662e-02,
#         5.2753e-01,  3.8839e-01,  9.6185e-01,  1.8841e-01,  3.0741e-01,
#        -8.7842e-01, -3.2442e-01,  1.1202e+00,  7.5126e-02,  4.2661e-01,
#        -6.0651e-01, -1.3893e-01,  4.7862e-02, -4.5158e-01,  9.3723e-02,
#         1.7463e-01,  1.0962e+00, -1.0044e+00,  6.3889e-02,  3.8002e-01,
#         2.1109e-01, -6.6247e-01, -4.0736e-01,  8.9442e-01, -6.0974e-01,
#        -1.8577e-01, -1.9913e-01, -6.9226e-01, -3.1806e-01, -7.8565e-01,
#         2.3831e-01,  1.2992e-01,  8.7721e-02,  4.3205e-01, -2.2662e-01,
#         3.1549e-01, -3.1748e-01, -2.4632e-03,  1.6615e-01,  4.2358e-01,
#        -1.8087e+00, -3.6699e-01,  2.3949e-01,  2.5458e+00,  3.6111e-01,
#         3.9486e-02,  4.8607e-01, -3.6974e-01,  5.7282e-02, -4.9317e-01,
#         2.2765e-01,  7.9966e-01,  2.1428e-01,  6.9811e-01,  1.1262e+00,
#        -1.3526e-01,  7.1972e-01, -9.9605e-04, -2.6842e-01, -8.3038e-01,
#         2.1780e-01,  3.4355e-01,  3.7731e-01, -4.0251e-01,  3.3124e-01,
#         1.2576e+00, -2.7196e-01, -8.6093e-01,  9.0053e-02, -2.4876e+00,
#         4.5200e-01,  6.6945e-01, -5.4648e-01, -1.0324e-01, -1.6979e-01,
#         5.9437e-01,  1.1280e+00,  7.5755e-01, -5.9160e-02,  1.5152e-01,
#        -2.8388e-01,  4.9452e-01, -9.1703e-01,  9.1289e-01, -3.0927e-01],
#       dtype=float32)

# %% [markdown]
# ### Finding most similar words
#
# Here we define a function to find the most similar words to a given word. The similarity is computed using the cosine similarity between the word embeddings. It can also accept multiple words, and it will take the average of the embeddings of the words to find the most similar words.

# %%
def most_similar(words, topn=10):
    query_emb = 0
    # If we have a list of words instead of one word
    # (bonus question)
    if type(words) == list:
        for word in words:
            query_emb += get_emb(word)
    else:
        query_emb = get_emb(words)

    query_emb = query_emb / np.linalg.norm(query_emb)

    # Large numpy vector with all cosine similarities
    # between emb and all other words
    cosines = np.dot(glove_embeddings_normed, query_emb)

    # topn most similar indexes corresponding to cosines
    idxs = np.argsort(cosines)[::-1][:topn]

    # pretty return with word and similarity
    return [(inv_index[idx], cosines[idx]) for idx in idxs]

# %%
most_similar("cpu")
# Out:
# [('cpu', np.float32(0.99999994)),
#  ('processor', np.float32(0.77934384)),
#  ('cpus', np.float32(0.7651844)),
#  ('microprocessor', np.float32(0.73606336)),
#  ('processors', np.float32(0.67348146)),
#  ('motherboard', np.float32(0.66757727)),
#  ('x86', np.float32(0.6655922)),
#  ('pentium', np.float32(0.64758503)),
#  ('gpu', np.float32(0.6448882)),
#  ('i/o', np.float32(0.63523525))]

# %%
most_similar("nvidia")
# Out:
# [('nvidia', np.float32(1.0)),
#  ('geforce', np.float32(0.70250356)),
#  ('gpu', np.float32(0.6787485)),
#  ('ati', np.float32(0.67037094)),
#  ('chipset', np.float32(0.63813114)),
#  ('gpus', np.float32(0.633038)),
#  ('amd', np.float32(0.6098824)),
#  ('chipsets', np.float32(0.6023344)),
#  ('tesla', np.float32(0.58550215)),
#  ('intel', np.float32(0.5631714))]

# %%
most_similar("1")
# Out:
# [('1', np.float32(1.0000001)),
#  ('2', np.float32(0.97136045)),
#  ('3', np.float32(0.9551016)),
#  ('4', np.float32(0.93552566)),
#  ('5', np.float32(0.9143885)),
#  ('6', np.float32(0.90160364)),
#  ('8', np.float32(0.8834145)),
#  ('7', np.float32(0.87454295)),
#  ('9', np.float32(0.8470948)),
#  ('10', np.float32(0.8159793))]

# %%
# bonus: sum of two word embeddings
most_similar(["toronto", "leaf"])
# Out:
# [('leaf', np.float32(0.7868253)),
#  ('toronto', np.float32(0.77712166)),
#  ('maple', np.float32(0.7656235)),
#  ('red', np.float32(0.6574254)),
#  ('buffalo', np.float32(0.6446778)),
#  ('leafs', np.float32(0.63587487)),
#  ('montreal', np.float32(0.63387585)),
#  ('boston', np.float32(0.626379)),
#  ('seattle', np.float32(0.62145466)),
#  ('cleveland', np.float32(0.62078816))]

# %% [markdown]
# ### Displaying vectors with  t-SNE

# %%
from sklearn.manifold import TSNE

word_emb_tsne = TSNE(perplexity=30).fit_transform(glove_embeddings_normed[:1000])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 40))
axis = plt.gca()
np.set_printoptions(suppress=True)
plt.scatter(word_emb_tsne[:, 0], word_emb_tsne[:, 1], marker=".", s=1)

for idx in range(1000):
    plt.annotate(inv_index[idx],
                 xy=(word_emb_tsne[idx, 0], word_emb_tsne[idx, 1]),
                 xytext=(0, 0), textcoords='offset points')
plt.savefig("tsne.png")
plt.show()

# %% [markdown]
# ### Using pre-trained embeddings in our model
#
# We want to use these pre-trained embeddings for transfer learning. This process is rather similar than transfer learning in image recognition: the features learnt on words might help us bootstrap the learning process, and increase performance if we don't have enough training data.
#
# - We initialize embedding matrix from the model with Glove embeddings:
#  - take all unique words from our BBC news dataset to build a vocabulary (`MAX_NB_WORDS = 20000`), and look up their Glove embedding
#  - place the Glove embedding at the corresponding index in the matrix
#  - if the word is not in the Glove vocabulary, we only place zeros in the matrix

# %%
EMBEDDING_DIM = 100

# prepare embedding matrix
nb_words_in_matrix = 0
nb_words = min(MAX_NB_WORDS, len(word_index))
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = get_emb(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector # Place the Glove embedding at the corresponding index in the matrix
        nb_words_in_matrix = nb_words_in_matrix + 1
        
print("added %d words in the embedding matrix" % nb_words_in_matrix)
# Out:
# added 17275 words in the embedding matrix

# %% [markdown]
# Build a layer with pre-trained embeddings:

# %%
pretrained_embedding_layer = Embedding(
    MAX_NB_WORDS, EMBEDDING_DIM,
    weights=[embedding_matrix],
)

# %% [markdown]
# ### A model with pre-trained Embeddings
#
# Now we can build a model with pre-trained embeddings. We will use the same architecture as before, but we will use the `pretrained_embedding_layer` as the first layer of the model.

# %%
model = Sequential([
    # Add the pre-defined and pre-trained embedding layer
    pretrained_embedding_layer,
    GlobalAveragePooling1D(),
    Dense(N_CLASSES, activation='softmax')
])

# Set the embedding layer's trainable attribute to False to not fine-tune the embeddings - you can try to change this
model.layers[0].trainable = False

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
model.fit(x_train, y_train, validation_split=0.1,
          epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6054 - loss: 1.3804 - val_accuracy: 0.8128 - val_loss: 1.2037
# Epoch 2/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8749 - loss: 1.0472 - val_accuracy: 0.8719 - val_loss: 0.9440
# Epoch 3/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.8378 - val_accuracy: 0.8916 - val_loss: 0.7755
# Epoch 4/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9138 - loss: 0.7003 - val_accuracy: 0.9015 - val_loss: 0.6604
# Epoch 5/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9188 - loss: 0.6046 - val_accuracy: 0.9163 - val_loss: 0.5778
# Epoch 6/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9232 - loss: 0.5345 - val_accuracy: 0.9064 - val_loss: 0.5161
# Epoch 7/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9297 - loss: 0.4810 - val_accuracy: 0.9212 - val_loss: 0.4683
# Epoch 8/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9325 - loss: 0.4389 - val_accuracy: 0.9261 - val_loss: 0.4304
# Epoch 9/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9347 - loss: 0.4048 - val_accuracy: 0.9261 - val_loss: 0.3995
# Epoch 10/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9385 - loss: 0.3766 - val_accuracy: 0.9212 - val_loss: 0.3739
# Epoch 11/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9429 - loss: 0.3528 - val_accuracy: 0.9261 - val_loss: 0.3524
# Epoch 12/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9435 - loss: 0.3326 - val_accuracy: 0.9261 - val_loss: 0.3340
# Epoch 13/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9462 - loss: 0.3150 - val_accuracy: 0.9360 - val_loss: 0.3182
# Epoch 14/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.2997 - val_accuracy: 0.9360 - val_loss: 0.3044
# Epoch 15/15
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9479 - loss: 0.2862 - val_accuracy: 0.9360 - val_loss: 0.2923

# %% [markdown]
# ### Reality check
#
# On small/medium datasets (few 10,000s) of reasonably large documents (e.g. more than a few paragraphs), simpler classification methods usually perform better, and are much more efficient to train and use. Here are two resources to go further, if you are curious:
# - Naive Bayes approach, using scikit-learn [http://scikit-learn.org/stable/datasets/twenty_newsgroups.html](http://scikit-learn.org/stable/datasets/twenty_newsgroups.html)
# - Alec Radford (OpenAI) gave a very interesting presentation, showing that you need a VERY large dataset to have real gains from GRU/LSTM in text classification [https://www.slideshare.net/odsc/alec-radfordodsc-presentation](https://www.slideshare.net/odsc/alec-radfordodsc-presentation)
#
# Training deep architectures from random init on text classification is usually a waste of time.
#
# However, when looking at features, one can see that classification using simple methods isn't very robust, and won't generalize well to slightly different domains (e.g. forum posts => emails)
#
# Nowadays, the strategy would be to use pre-trained deep network (BERT) to extract features and fit a linear classifer on top of this. This is especially useful when classifying short texts (e.g. one or a few sentences) as this kind of tasks can be very sensitive to understanding the meaning resulting from intra-sentence interactions between words. The next session on attentional mechanisms and pre-trained transformer-based word models will explain this in more details.
